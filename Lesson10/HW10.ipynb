# %% [markdown]
# # Neural machine translation

# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# ## Download and prepare the dataset
#
# We'll use a language dataset provided by http://www.manythings.org/anki/

# %%
# !wget http://www.manythings.org/anki/spa-eng.zip
# Out:
# --2022-07-11 20:31:02--  http://www.manythings.org/anki/spa-eng.zip
# Resolving www.manythings.org (www.manythings.org)... 173.254.30.110
# Connecting to www.manythings.org (www.manythings.org)|173.254.30.110|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5320329 (5.1M) [application/zip]
# Saving to: ‘spa-eng.zip’
#
# spa-eng.zip         100%[===================>]   5.07M  20.7MB/s    in 0.2s
#
# 2022-07-11 20:31:02 (20.7 MB/s) - ‘spa-eng.zip’ saved [5320329/5320329]

# %%
# !mkdir spa-eng
# !unzip spa-eng.zip -d spa-eng/
# Out:
# Archive:  spa-eng.zip
#   inflating: spa-eng/_about.txt
#   inflating: spa-eng/spa.txt

# %%
# !ls /content/spa-eng/ -lah
# Out:
# total 20M
# drwxr-xr-x 2 root root 4.0K Jul 11 20:31 .
# drwxr-xr-x 1 root root 4.0K Jul 11 20:31 ..
# -rw-r--r-- 1 root root 1.5K May  2 01:29 _about.txt
# -rw-r--r-- 1 root root  20M May  2 01:29 spa.txt

# %%
# Download the file
path_to_file = "/content/spa-eng/spa.txt"

# %%
def preprocess_sentence(w):
  w = w.lower().strip()

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Zа-яА-Я?.!,']+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
preprocess_sentence("I can't go.")
# Out:
# "<start> i can't go . <end>"

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENG, RUS]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')[:2]]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, sp = create_dataset(path_to_file, None)
print(en[0])
print(sp[0])
# Out:
# <start> go . <end>
# <start> ve . <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang)

  tensor = lang_tokenizer.texts_to_sequences(lang)

  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %% [markdown]
# ### Limit the size of the dataset to experiment faster (optional)

# %%
len(en), len(sp)
# Out:
# (138440, 138440)

# %%
# Try experimenting with the size of that dataset
num_examples = 100000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 80000 80000 20000 20000

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 48 ----> quiero
# 52 ----> este
# 517 ----> diccionario
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 4 ----> i
# 29 ----> want
# 16 ----> this
# 540 ----> dictionary
# 3 ----> .
# 2 ----> <end>

# %% [markdown]
# ### Create a tf.data dataset

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 64
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 300
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([64, 23]), TensorShape([64, 14]))

# %%
class Encoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
    super(Encoder, self).__init__()
    self.batch_sz = batch_sz
    self.enc_units = enc_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.enc_units,
                                   return_sequences=False,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    

  def call(self, x, hidden):
    x = self.embedding(x)
    output, state = self.gru(x, initial_state = hidden)
    return state

  def initialize_hidden_state(self):
    return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_hidden = encoder(example_input_batch, sample_hidden)
# print ('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print ('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))
# Out:
# Encoder Hidden state shape: (batch size, units) (64, 1024)

# %%
class Decoder(tf.keras.Model):
  def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
    super(Decoder, self).__init__()
    self.batch_sz = batch_sz
    self.dec_units = dec_units
    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.dec_units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc = tf.keras.layers.Dense(vocab_size)

  def call(self, x, hidden):
    # enc_output shape == (batch_size, max_length, hidden_size)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x, initial_state=hidden)

    # output shape == (batch_size * 1, hidden_size)
    output = tf.reshape(output, (-1, output.shape[2]))

    # output shape == (batch_size, vocab)
    x = self.fc(output)

    return x, state

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)

decoder_sample_x, decoder_sample_h = decoder(tf.random.uniform((BATCH_SIZE, 1)),
                                      sample_hidden)

# %%
decoder_sample_x.shape
# Out:
# TensorShape([64, 10452])

# %%
decoder_sample_h.shape
# Out:
# TensorShape([64, 1024])

# %% [markdown]
# ## Define the optimizer and the loss function

# %%
optimizer = tf.keras.optimizers.Adam()

loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoints (Object-based saving)

# %%
checkpoint_dir = './training_nmt_checkpoints'

checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %%
<s> w1 w2 w3 w4 <end>
0    t
# Out:
#   File "<ipython-input-29-a3d3c9e13ec9>", line 1
#     <s> w1 w2 w3 w4 <end>
#     ^
# SyntaxError: invalid syntax

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
  loss = 0

  with tf.GradientTape() as tape:
    enc_hidden = encoder(inp, enc_hidden)

    dec_hidden = enc_hidden

    dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

    # Teacher forcing - feeding the target as the next input
    for t in range(1, targ.shape[1]):
      # passing enc_output to the decoder
      predictions, dec_hidden = decoder(dec_input, dec_hidden)

      loss += loss_function(targ[:, t], predictions)

      # using teacher forcing
      dec_input = tf.expand_dims(targ[:, t], 1)

  batch_loss = (loss / int(targ.shape[1]))

  variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, variables)

  optimizer.apply_gradients(zip(gradients, variables))

  return batch_loss

# %%
EPOCHS = 50

for epoch in range(EPOCHS):
  start = time.time()

  enc_hidden = encoder.initialize_hidden_state()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
    batch_loss = train_step(inp, targ, enc_hidden)
    total_loss += batch_loss

    if batch % 100 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                   batch,
                                                   batch_loss.numpy()))
  # saving (checkpoint) the model every 2 epochs
  if (epoch + 1) % 2 == 0:
    checkpoint.save(file_prefix = checkpoint_prefix)

  print('Epoch {} Loss {:.4f}'.format(epoch + 1,
                                      total_loss / steps_per_epoch))
  print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 4.7617
# Epoch 1 Batch 100 Loss 2.2180
# Epoch 1 Batch 200 Loss 1.9873
# Epoch 1 Batch 300 Loss 1.9235
# Epoch 1 Batch 400 Loss 1.8869
# Epoch 1 Batch 500 Loss 1.6669
# Epoch 1 Batch 600 Loss 1.6997
# Epoch 1 Batch 700 Loss 1.4613
# Epoch 1 Batch 800 Loss 1.4864
# Epoch 1 Batch 900 Loss 1.3359
# Epoch 1 Batch 1000 Loss 1.5138
# Epoch 1 Batch 1100 Loss 1.3788
# Epoch 1 Batch 1200 Loss 1.1847
# Epoch 1 Loss 1.7144
# Time taken for 1 epoch 94.29506540298462 sec
#
# Epoch 2 Batch 0 Loss 1.2033
# Epoch 2 Batch 100 Loss 1.2029
# Epoch 2 Batch 200 Loss 1.1276
# Epoch 2 Batch 300 Loss 1.0559
# Epoch 2 Batch 400 Loss 0.9195
# Epoch 2 Batch 500 Loss 0.9751
# Epoch 2 Batch 600 Loss 0.8718
# Epoch 2 Batch 700 Loss 0.8700
# Epoch 2 Batch 800 Loss 1.0336
# Epoch 2 Batch 900 Loss 0.8428
# Epoch 2 Batch 1000 Loss 0.8894
# Epoch 2 Batch 1100 Loss 0.7440
# Epoch 2 Batch 1200 Loss 0.8017
# Epoch 2 Loss 0.9393
# Time taken for 1 epoch 81.91680097579956 sec
#
# Epoch 3 Batch 0 Loss 0.5571
# Epoch 3 Batch 100 Loss 0.5599
# Epoch 3 Batch 200 Loss 0.5546
# Epoch 3 Batch 300 Loss 0.5790
# Epoch 3 Batch 400 Loss 0.5519
# Epoch 3 Batch 500 Loss 0.5715
# Epoch 3 Batch 600 Loss 0.6041
# Epoch 3 Batch 700 Loss 0.5246
# Epoch 3 Batch 800 Loss 0.4791
# Epoch 3 Batch 900 Loss 0.4626
# Epoch 3 Batch 1000 Loss 0.5426
# Epoch 3 Batch 1100 Loss 0.5243
# Epoch 3 Batch 1200 Loss 0.6107
# Epoch 3 Loss 0.5567
# Time taken for 1 epoch 83.06309390068054 sec
#
# Epoch 4 Batch 0 Loss 0.2638
# Epoch 4 Batch 100 Loss 0.3065
# Epoch 4 Batch 200 Loss 0.2837
# Epoch 4 Batch 300 Loss 0.3290
# Epoch 4 Batch 400 Loss 0.3710
# Epoch 4 Batch 500 Loss 0.3854
# Epoch 4 Batch 600 Loss 0.3602
# Epoch 4 Batch 700 Loss 0.3443
# Epoch 4 Batch 800 Loss 0.3368
# Epoch 4 Batch 900 Loss 0.3024
# Epoch 4 Batch 1000 Loss 0.3986
# Epoch 4 Batch 1100 Loss 0.3256
# Epoch 4 Batch 1200 Loss 0.3905
# Epoch 4 Loss 0.3362
# Time taken for 1 epoch 83.86197853088379 sec
#
# Epoch 5 Batch 0 Loss 0.2161
# Epoch 5 Batch 100 Loss 0.1969
# Epoch 5 Batch 200 Loss 0.1744
# Epoch 5 Batch 300 Loss 0.1868
# Epoch 5 Batch 400 Loss 0.1821
# Epoch 5 Batch 500 Loss 0.2366
# Epoch 5 Batch 600 Loss 0.2432
# Epoch 5 Batch 700 Loss 0.2187
# Epoch 5 Batch 800 Loss 0.2197
# Epoch 5 Batch 900 Loss 0.2830
# Epoch 5 Batch 1000 Loss 0.2059
# Epoch 5 Batch 1100 Loss 0.2083
# Epoch 5 Batch 1200 Loss 0.2573
# Epoch 5 Loss 0.2135
# Time taken for 1 epoch 83.48721289634705 sec
#
# Epoch 6 Batch 0 Loss 0.1386
# Epoch 6 Batch 100 Loss 0.0905
# Epoch 6 Batch 200 Loss 0.0892
# Epoch 6 Batch 300 Loss 0.1215
# Epoch 6 Batch 400 Loss 0.1240
# Epoch 6 Batch 500 Loss 0.1470
# Epoch 6 Batch 600 Loss 0.1489
# Epoch 6 Batch 700 Loss 0.1685
# Epoch 6 Batch 800 Loss 0.1133
# Epoch 6 Batch 900 Loss 0.1664
# Epoch 6 Batch 1000 Loss 0.1664
# Epoch 6 Batch 1100 Loss 0.1820
# Epoch 6 Batch 1200 Loss 0.2545
# Epoch 6 Loss 0.1497
# Time taken for 1 epoch 84.32378768920898 sec
#
# Epoch 7 Batch 0 Loss 0.1206
# Epoch 7 Batch 100 Loss 0.1190
# Epoch 7 Batch 200 Loss 0.0820
# Epoch 7 Batch 300 Loss 0.1144
# Epoch 7 Batch 400 Loss 0.1172
# Epoch 7 Batch 500 Loss 0.0928
# Epoch 7 Batch 600 Loss 0.1233
# Epoch 7 Batch 700 Loss 0.1493
# Epoch 7 Batch 800 Loss 0.1434
# Epoch 7 Batch 900 Loss 0.1376
# Epoch 7 Batch 1000 Loss 0.1388
# Epoch 7 Batch 1100 Loss 0.1387
# Epoch 7 Batch 1200 Loss 0.1305
# Epoch 7 Loss 0.1174
# Time taken for 1 epoch 83.50984215736389 sec
#
# Epoch 8 Batch 0 Loss 0.1096
# Epoch 8 Batch 100 Loss 0.1069
# Epoch 8 Batch 200 Loss 0.0941
# Epoch 8 Batch 300 Loss 0.0998
# Epoch 8 Batch 400 Loss 0.0519
# Epoch 8 Batch 500 Loss 0.1292
# Epoch 8 Batch 600 Loss 0.1027
# Epoch 8 Batch 700 Loss 0.0909
# Epoch 8 Batch 800 Loss 0.0703
# Epoch 8 Batch 900 Loss 0.1116
# Epoch 8 Batch 1000 Loss 0.1434
# Epoch 8 Batch 1100 Loss 0.1694
# Epoch 8 Batch 1200 Loss 0.1128
# Epoch 8 Loss 0.1000
# Time taken for 1 epoch 84.19027090072632 sec
#
# Epoch 9 Batch 0 Loss 0.0630
# Epoch 9 Batch 100 Loss 0.0699
# Epoch 9 Batch 200 Loss 0.0633
# Epoch 9 Batch 300 Loss 0.0677
# Epoch 9 Batch 400 Loss 0.0521
# Epoch 9 Batch 500 Loss 0.0612
# Epoch 9 Batch 600 Loss 0.0985
# Epoch 9 Batch 700 Loss 0.0809
# Epoch 9 Batch 800 Loss 0.1164
# Epoch 9 Batch 900 Loss 0.0926
# Epoch 9 Batch 1000 Loss 0.1307
# Epoch 9 Batch 1100 Loss 0.1066
# Epoch 9 Batch 1200 Loss 0.0876
# Epoch 9 Loss 0.0898
# Time taken for 1 epoch 83.38408017158508 sec
#
# Epoch 10 Batch 0 Loss 0.0787
# Epoch 10 Batch 100 Loss 0.0462
# Epoch 10 Batch 200 Loss 0.0768
# Epoch 10 Batch 300 Loss 0.0574
# Epoch 10 Batch 400 Loss 0.0691
# Epoch 10 Batch 500 Loss 0.0790
# Epoch 10 Batch 600 Loss 0.0916
# Epoch 10 Batch 700 Loss 0.1056
# Epoch 10 Batch 800 Loss 0.0721
# Epoch 10 Batch 900 Loss 0.0642
# Epoch 10 Batch 1000 Loss 0.0889
# Epoch 10 Batch 1100 Loss 0.1047
# Epoch 10 Batch 1200 Loss 0.1071
# Epoch 10 Loss 0.0826
# Time taken for 1 epoch 84.04900527000427 sec
#
# Epoch 11 Batch 0 Loss 0.0820
# Epoch 11 Batch 100 Loss 0.0716
# Epoch 11 Batch 200 Loss 0.0449
# Epoch 11 Batch 300 Loss 0.0708
# Epoch 11 Batch 400 Loss 0.0555
# Epoch 11 Batch 500 Loss 0.0409
# Epoch 11 Batch 600 Loss 0.0762
# Epoch 11 Batch 700 Loss 0.1166
# Epoch 11 Batch 800 Loss 0.0533
# Epoch 11 Batch 900 Loss 0.1104
# Epoch 11 Batch 1000 Loss 0.0818
# Epoch 11 Batch 1100 Loss 0.0775
# Epoch 11 Batch 1200 Loss 0.0926
# Epoch 11 Loss 0.0793
# Time taken for 1 epoch 83.44010066986084 sec
#
# Epoch 12 Batch 0 Loss 0.1023
# Epoch 12 Batch 100 Loss 0.0751
# Epoch 12 Batch 200 Loss 0.0628
# Epoch 12 Batch 300 Loss 0.0781
# Epoch 12 Batch 400 Loss 0.0661
# Epoch 12 Batch 500 Loss 0.0651
# Epoch 12 Batch 600 Loss 0.0979
# Epoch 12 Batch 700 Loss 0.0569
# Epoch 12 Batch 800 Loss 0.0600
# Epoch 12 Batch 900 Loss 0.0800
# Epoch 12 Batch 1000 Loss 0.1146
# Epoch 12 Batch 1100 Loss 0.1035
# Epoch 12 Batch 1200 Loss 0.0660
# Epoch 12 Loss 0.0767
# Time taken for 1 epoch 84.15815091133118 sec
#
# Epoch 13 Batch 0 Loss 0.0493
# Epoch 13 Batch 100 Loss 0.0678
# Epoch 13 Batch 200 Loss 0.0817
# Epoch 13 Batch 300 Loss 0.0768
# Epoch 13 Batch 400 Loss 0.0557
# Epoch 13 Batch 500 Loss 0.0570
# Epoch 13 Batch 600 Loss 0.0632
# Epoch 13 Batch 700 Loss 0.0562
# Epoch 13 Batch 800 Loss 0.0656
# Epoch 13 Batch 900 Loss 0.0997
# Epoch 13 Batch 1000 Loss 0.1085
# Epoch 13 Batch 1100 Loss 0.0758
# Epoch 13 Batch 1200 Loss 0.1338
# Epoch 13 Loss 0.0736
# Time taken for 1 epoch 83.1977698802948 sec
#
# Epoch 14 Batch 0 Loss 0.0657
# Epoch 14 Batch 100 Loss 0.0328
# Epoch 14 Batch 200 Loss 0.0332
# Epoch 14 Batch 300 Loss 0.0725
# Epoch 14 Batch 400 Loss 0.0665
# Epoch 14 Batch 500 Loss 0.0579
# Epoch 14 Batch 600 Loss 0.0648
# Epoch 14 Batch 700 Loss 0.0733
# Epoch 14 Batch 800 Loss 0.0712
# Epoch 14 Batch 900 Loss 0.0863
# Epoch 14 Batch 1000 Loss 0.0795
# Epoch 14 Batch 1100 Loss 0.0892
# Epoch 14 Batch 1200 Loss 0.0677
# Epoch 14 Loss 0.0718
# Time taken for 1 epoch 83.83512115478516 sec
#
# Epoch 15 Batch 0 Loss 0.0746
# Epoch 15 Batch 100 Loss 0.0374
# Epoch 15 Batch 200 Loss 0.0541
# Epoch 15 Batch 300 Loss 0.0810
# Epoch 15 Batch 400 Loss 0.0699
# Epoch 15 Batch 500 Loss 0.0694
# Epoch 15 Batch 600 Loss 0.0666
# Epoch 15 Batch 700 Loss 0.0664
# Epoch 15 Batch 800 Loss 0.1158
# Epoch 15 Batch 900 Loss 0.0776
# Epoch 15 Batch 1000 Loss 0.0650
# Epoch 15 Batch 1100 Loss 0.0836
# Epoch 15 Batch 1200 Loss 0.1272
# Epoch 15 Loss 0.0723
# Time taken for 1 epoch 83.25643873214722 sec
#
# Epoch 16 Batch 0 Loss 0.0509
# Epoch 16 Batch 100 Loss 0.0599
# Epoch 16 Batch 200 Loss 0.0304
# Epoch 16 Batch 300 Loss 0.0615
# Epoch 16 Batch 400 Loss 0.0563
# Epoch 16 Batch 500 Loss 0.0713
# Epoch 16 Batch 600 Loss 0.0751
# Epoch 16 Batch 700 Loss 0.0620
# Epoch 16 Batch 800 Loss 0.0874
# Epoch 16 Batch 900 Loss 0.0619
# Epoch 16 Batch 1000 Loss 0.0808
# Epoch 16 Batch 1100 Loss 0.1137
# Epoch 16 Batch 1200 Loss 0.0684
# Epoch 16 Loss 0.0701
# Time taken for 1 epoch 84.08726024627686 sec
#
# Epoch 17 Batch 0 Loss 0.0440
# Epoch 17 Batch 100 Loss 0.0683
# Epoch 17 Batch 200 Loss 0.0484
# Epoch 17 Batch 300 Loss 0.0422
# Epoch 17 Batch 400 Loss 0.0777
# Epoch 17 Batch 500 Loss 0.0880
# Epoch 17 Batch 600 Loss 0.0880
# Epoch 17 Batch 700 Loss 0.0702
# Epoch 17 Batch 800 Loss 0.0634
# Epoch 17 Batch 900 Loss 0.0795
# Epoch 17 Batch 1000 Loss 0.0899
# Epoch 17 Batch 1100 Loss 0.0706
# Epoch 17 Batch 1200 Loss 0.0659
# Epoch 17 Loss 0.0695
# Time taken for 1 epoch 83.52205157279968 sec
#
# Epoch 18 Batch 0 Loss 0.0500
# Epoch 18 Batch 100 Loss 0.0565
# Epoch 18 Batch 200 Loss 0.0983
# Epoch 18 Batch 300 Loss 0.0470
# Epoch 18 Batch 400 Loss 0.0505
# Epoch 18 Batch 500 Loss 0.0705
# Epoch 18 Batch 600 Loss 0.0718
# Epoch 18 Batch 700 Loss 0.0472
# Epoch 18 Batch 800 Loss 0.0440
# Epoch 18 Batch 900 Loss 0.0678
# Epoch 18 Batch 1000 Loss 0.0954
# Epoch 18 Batch 1100 Loss 0.0675
# Epoch 18 Batch 1200 Loss 0.0813
# Epoch 18 Loss 0.0701
# Time taken for 1 epoch 83.99986863136292 sec
#
# Epoch 19 Batch 0 Loss 0.0780
# Epoch 19 Batch 100 Loss 0.0505
# Epoch 19 Batch 200 Loss 0.0550
# Epoch 19 Batch 300 Loss 0.0825
# Epoch 19 Batch 400 Loss 0.0404
# Epoch 19 Batch 500 Loss 0.0628
# Epoch 19 Batch 600 Loss 0.0767
# Epoch 19 Batch 700 Loss 0.0545
# Epoch 19 Batch 800 Loss 0.0804
# Epoch 19 Batch 900 Loss 0.0617
# Epoch 19 Batch 1000 Loss 0.0738
# Epoch 19 Batch 1100 Loss 0.0435
# Epoch 19 Batch 1200 Loss 0.1040
# Epoch 19 Loss 0.0693
# Time taken for 1 epoch 83.34417676925659 sec
#
# Epoch 20 Batch 0 Loss 0.0592
# Epoch 20 Batch 100 Loss 0.0564
# Epoch 20 Batch 200 Loss 0.0733
# Epoch 20 Batch 300 Loss 0.0597
# Epoch 20 Batch 400 Loss 0.0739
# Epoch 20 Batch 500 Loss 0.0525
# Epoch 20 Batch 600 Loss 0.0558
# Epoch 20 Batch 700 Loss 0.0685
# Epoch 20 Batch 800 Loss 0.0792
# Epoch 20 Batch 900 Loss 0.0683
# Epoch 20 Batch 1000 Loss 0.0490
# Epoch 20 Batch 1100 Loss 0.1202
# Epoch 20 Batch 1200 Loss 0.1146
# Epoch 20 Loss 0.0687
# Time taken for 1 epoch 84.07645606994629 sec
#
# Epoch 21 Batch 0 Loss 0.0410
# Epoch 21 Batch 100 Loss 0.0571
# Epoch 21 Batch 200 Loss 0.0486
# Epoch 21 Batch 300 Loss 0.0633
# Epoch 21 Batch 400 Loss 0.0648
# Epoch 21 Batch 500 Loss 0.0914
# Epoch 21 Batch 600 Loss 0.1126
# Epoch 21 Batch 700 Loss 0.0730
# Epoch 21 Batch 800 Loss 0.0848
# Epoch 21 Batch 900 Loss 0.1277
# Epoch 21 Batch 1000 Loss 0.0671
# Epoch 21 Batch 1100 Loss 0.1306
# Epoch 21 Batch 1200 Loss 0.0690
# Epoch 21 Loss 0.0677
# Time taken for 1 epoch 83.53337812423706 sec
#
# Epoch 22 Batch 0 Loss 0.0256
# Epoch 22 Batch 100 Loss 0.0753
# Epoch 22 Batch 200 Loss 0.0393
# Epoch 22 Batch 300 Loss 0.0567
# Epoch 22 Batch 400 Loss 0.0555
# Epoch 22 Batch 500 Loss 0.0658
# Epoch 22 Batch 600 Loss 0.0538
# Epoch 22 Batch 700 Loss 0.0632
# Epoch 22 Batch 800 Loss 0.0802
# Epoch 22 Batch 900 Loss 0.0533
# Epoch 22 Batch 1000 Loss 0.0906
# Epoch 22 Batch 1100 Loss 0.0785
# Epoch 22 Batch 1200 Loss 0.0617
# Epoch 22 Loss 0.0684
# Time taken for 1 epoch 84.35209012031555 sec
#
# Epoch 23 Batch 0 Loss 0.0355
# Epoch 23 Batch 100 Loss 0.0680
# Epoch 23 Batch 200 Loss 0.0799
# Epoch 23 Batch 300 Loss 0.0666
# Epoch 23 Batch 400 Loss 0.0419
# Epoch 23 Batch 500 Loss 0.0405
# Epoch 23 Batch 600 Loss 0.0865
# Epoch 23 Batch 700 Loss 0.0505
# Epoch 23 Batch 800 Loss 0.0685
# Epoch 23 Batch 900 Loss 0.1578
# Epoch 23 Batch 1000 Loss 0.0647
# Epoch 23 Batch 1100 Loss 0.0939
# Epoch 23 Batch 1200 Loss 0.0920
# Epoch 23 Loss 0.0689
# Time taken for 1 epoch 83.53172469139099 sec
#
# Epoch 24 Batch 0 Loss 0.0500
# Epoch 24 Batch 100 Loss 0.0418
# Epoch 24 Batch 200 Loss 0.0459
# Epoch 24 Batch 300 Loss 0.0508
# Epoch 24 Batch 400 Loss 0.0702
# Epoch 24 Batch 500 Loss 0.0594
# Epoch 24 Batch 600 Loss 0.0894
# Epoch 24 Batch 700 Loss 0.1023
# Epoch 24 Batch 800 Loss 0.0666
# Epoch 24 Batch 900 Loss 0.0858
# Epoch 24 Batch 1000 Loss 0.0495
# Epoch 24 Batch 1100 Loss 0.0832
# Epoch 24 Batch 1200 Loss 0.1088
# Epoch 24 Loss 0.0685
# Time taken for 1 epoch 84.07095193862915 sec
#
# Epoch 25 Batch 0 Loss 0.0512
# Epoch 25 Batch 100 Loss 0.0736
# Epoch 25 Batch 200 Loss 0.0532
# Epoch 25 Batch 300 Loss 0.0493
# Epoch 25 Batch 400 Loss 0.0610
# Epoch 25 Batch 500 Loss 0.0732
# Epoch 25 Batch 600 Loss 0.0802
# Epoch 25 Batch 700 Loss 0.0536
# Epoch 25 Batch 800 Loss 0.0890
# Epoch 25 Batch 900 Loss 0.0606
# Epoch 25 Batch 1000 Loss 0.0830
# Epoch 25 Batch 1100 Loss 0.0894
# Epoch 25 Batch 1200 Loss 0.0995
# Epoch 25 Loss 0.0689
# Time taken for 1 epoch 83.47948503494263 sec
#
# Epoch 26 Batch 0 Loss 0.0646
# Epoch 26 Batch 100 Loss 0.0516
# Epoch 26 Batch 200 Loss 0.0694
# Epoch 26 Batch 300 Loss 0.0615
# Epoch 26 Batch 400 Loss 0.0466
# Epoch 26 Batch 500 Loss 0.0340
# Epoch 26 Batch 600 Loss 0.0560
# Epoch 26 Batch 700 Loss 0.0684
# Epoch 26 Batch 800 Loss 0.0828
# Epoch 26 Batch 900 Loss 0.0824
# Epoch 26 Batch 1000 Loss 0.0718
# Epoch 26 Batch 1100 Loss 0.1051
# Epoch 26 Batch 1200 Loss 0.0594
# Epoch 26 Loss 0.0692
# Time taken for 1 epoch 84.36363434791565 sec
#
# Epoch 27 Batch 0 Loss 0.0474
# Epoch 27 Batch 100 Loss 0.0303
# Epoch 27 Batch 200 Loss 0.0593
# Epoch 27 Batch 300 Loss 0.0664
# Epoch 27 Batch 400 Loss 0.0778
# Epoch 27 Batch 500 Loss 0.0403
# Epoch 27 Batch 600 Loss 0.0818
# Epoch 27 Batch 700 Loss 0.1034
# Epoch 27 Batch 800 Loss 0.0924
# Epoch 27 Batch 900 Loss 0.0742
# Epoch 27 Batch 1000 Loss 0.0606
# Epoch 27 Batch 1100 Loss 0.1051
# Epoch 27 Batch 1200 Loss 0.1075
# Epoch 27 Loss 0.0688
# Time taken for 1 epoch 83.35894966125488 sec
#
# Epoch 28 Batch 0 Loss 0.0466
# Epoch 28 Batch 100 Loss 0.0606
# Epoch 28 Batch 200 Loss 0.0809
# Epoch 28 Batch 300 Loss 0.0409
# Epoch 28 Batch 400 Loss 0.0994
# Epoch 28 Batch 500 Loss 0.0900
# Epoch 28 Batch 600 Loss 0.0665
# Epoch 28 Batch 700 Loss 0.0769
# Epoch 28 Batch 800 Loss 0.0837
# Epoch 28 Batch 900 Loss 0.0806
# Epoch 28 Batch 1000 Loss 0.1014
# Epoch 28 Batch 1100 Loss 0.0758
# Epoch 28 Batch 1200 Loss 0.0730
# Epoch 28 Loss 0.0692
# Time taken for 1 epoch 84.1155092716217 sec
#
# Epoch 29 Batch 0 Loss 0.0301
# Epoch 29 Batch 100 Loss 0.0433
# Epoch 29 Batch 200 Loss 0.0355
# Epoch 29 Batch 300 Loss 0.0418
# Epoch 29 Batch 400 Loss 0.0426
# Epoch 29 Batch 500 Loss 0.0961
# Epoch 29 Batch 600 Loss 0.0844
# Epoch 29 Batch 700 Loss 0.0872
# Epoch 29 Batch 800 Loss 0.0951
# Epoch 29 Batch 900 Loss 0.0770
# Epoch 29 Batch 1000 Loss 0.0904
# Epoch 29 Batch 1100 Loss 0.1041
# Epoch 29 Batch 1200 Loss 0.0820
# Epoch 29 Loss 0.0691
# Time taken for 1 epoch 83.26107549667358 sec
#
# Epoch 30 Batch 0 Loss 0.0250
# Epoch 30 Batch 100 Loss 0.0302
# Epoch 30 Batch 200 Loss 0.0515
# Epoch 30 Batch 300 Loss 0.0428
# Epoch 30 Batch 400 Loss 0.0441
# Epoch 30 Batch 500 Loss 0.0678
# Epoch 30 Batch 600 Loss 0.0960
# Epoch 30 Batch 700 Loss 0.1310
# Epoch 30 Batch 800 Loss 0.0725
# Epoch 30 Batch 900 Loss 0.0745
# Epoch 30 Batch 1000 Loss 0.0852
# Epoch 30 Batch 1100 Loss 0.1080
# Epoch 30 Batch 1200 Loss 0.0722
# Epoch 30 Loss 0.0703
# Time taken for 1 epoch 84.03666138648987 sec
#
# Epoch 31 Batch 0 Loss 0.0769
# Epoch 31 Batch 100 Loss 0.0805
# Epoch 31 Batch 200 Loss 0.0773
# Epoch 31 Batch 300 Loss 0.0510
# Epoch 31 Batch 400 Loss 0.0686
# Epoch 31 Batch 500 Loss 0.0598
# Epoch 31 Batch 600 Loss 0.0473
# Epoch 31 Batch 700 Loss 0.0823
# Epoch 31 Batch 800 Loss 0.0719
# Epoch 31 Batch 900 Loss 0.0901
# Epoch 31 Batch 1000 Loss 0.0638
# Epoch 31 Batch 1100 Loss 0.1345
# Epoch 31 Batch 1200 Loss 0.1137
# Epoch 31 Loss 0.0700
# Time taken for 1 epoch 83.4953875541687 sec
#
# Epoch 32 Batch 0 Loss 0.0421
# Epoch 32 Batch 100 Loss 0.0638
# Epoch 32 Batch 200 Loss 0.0816
# Epoch 32 Batch 300 Loss 0.0759
# Epoch 32 Batch 400 Loss 0.0383
# Epoch 32 Batch 500 Loss 0.1333
# Epoch 32 Batch 600 Loss 0.0392
# Epoch 32 Batch 700 Loss 0.0767
# Epoch 32 Batch 800 Loss 0.1250
# Epoch 32 Batch 900 Loss 0.0813
# Epoch 32 Batch 1000 Loss 0.1260
# Epoch 32 Batch 1100 Loss 0.0881
# Epoch 32 Batch 1200 Loss 0.0635
# Epoch 32 Loss 0.0712
# Time taken for 1 epoch 84.0553023815155 sec
#
# Epoch 33 Batch 0 Loss 0.0650
# Epoch 33 Batch 100 Loss 0.0395
# Epoch 33 Batch 200 Loss 0.0525
# Epoch 33 Batch 300 Loss 0.0539
# Epoch 33 Batch 400 Loss 0.0693
# Epoch 33 Batch 500 Loss 0.0642
# Epoch 33 Batch 600 Loss 0.1088
# Epoch 33 Batch 700 Loss 0.0553
# Epoch 33 Batch 800 Loss 0.0943
# Epoch 33 Batch 900 Loss 0.0849
# Epoch 33 Batch 1000 Loss 0.0861
# Epoch 33 Batch 1100 Loss 0.0963
# Epoch 33 Batch 1200 Loss 0.0882
# Epoch 33 Loss 0.0718
# Time taken for 1 epoch 83.21995615959167 sec
#
# Epoch 34 Batch 0 Loss 0.0483
# Epoch 34 Batch 100 Loss 0.0518
# Epoch 34 Batch 200 Loss 0.0674
# Epoch 34 Batch 300 Loss 0.0692
# Epoch 34 Batch 400 Loss 0.0762
# Epoch 34 Batch 500 Loss 0.0671
# Epoch 34 Batch 600 Loss 0.0708
# Epoch 34 Batch 700 Loss 0.0578
# Epoch 34 Batch 800 Loss 0.0539
# Epoch 34 Batch 900 Loss 0.0482
# Epoch 34 Batch 1000 Loss 0.0690
# Epoch 34 Batch 1100 Loss 0.0956
# Epoch 34 Batch 1200 Loss 0.0691
# Epoch 34 Loss 0.0711
# Time taken for 1 epoch 83.92333817481995 sec
#
# Epoch 35 Batch 0 Loss 0.0393
# Epoch 35 Batch 100 Loss 0.0653
# Epoch 35 Batch 200 Loss 0.0359
# Epoch 35 Batch 300 Loss 0.0660
# Epoch 35 Batch 400 Loss 0.0771
# Epoch 35 Batch 500 Loss 0.0740
# Epoch 35 Batch 600 Loss 0.0642
# Epoch 35 Batch 700 Loss 0.1320
# Epoch 35 Batch 800 Loss 0.0584
# Epoch 35 Batch 900 Loss 0.0859
# Epoch 35 Batch 1000 Loss 0.0983
# Epoch 35 Batch 1100 Loss 0.0582
# Epoch 35 Batch 1200 Loss 0.0562
# Epoch 35 Loss 0.0711
# Time taken for 1 epoch 83.3095645904541 sec
#
# Epoch 36 Batch 0 Loss 0.0279
# Epoch 36 Batch 100 Loss 0.0683
# Epoch 36 Batch 200 Loss 0.1143
# Epoch 36 Batch 300 Loss 0.0699
# Epoch 36 Batch 400 Loss 0.0561
# Epoch 36 Batch 500 Loss 0.0379
# Epoch 36 Batch 600 Loss 0.0869
# Epoch 36 Batch 700 Loss 0.0823
# Epoch 36 Batch 800 Loss 0.1031
# Epoch 36 Batch 900 Loss 0.0558
# Epoch 36 Batch 1000 Loss 0.0604
# Epoch 36 Batch 1100 Loss 0.1055
# Epoch 36 Batch 1200 Loss 0.0580
# Epoch 36 Loss 0.0719
# Time taken for 1 epoch 83.96157240867615 sec
#
# Epoch 37 Batch 0 Loss 0.1120
# Epoch 37 Batch 100 Loss 0.0453
# Epoch 37 Batch 200 Loss 0.0395
# Epoch 37 Batch 300 Loss 0.0661
# Epoch 37 Batch 400 Loss 0.0663
# Epoch 37 Batch 500 Loss 0.0798
# Epoch 37 Batch 600 Loss 0.0997
# Epoch 37 Batch 700 Loss 0.0709
# Epoch 37 Batch 800 Loss 0.1152
# Epoch 37 Batch 900 Loss 0.0699
# Epoch 37 Batch 1000 Loss 0.1072
# Epoch 37 Batch 1100 Loss 0.0610
# Epoch 37 Batch 1200 Loss 0.1047
# Epoch 37 Loss 0.0728
# Time taken for 1 epoch 83.5470187664032 sec
#
# Epoch 38 Batch 0 Loss 0.0546
# Epoch 38 Batch 100 Loss 0.0427
# Epoch 38 Batch 200 Loss 0.0354
# Epoch 38 Batch 300 Loss 0.0605
# Epoch 38 Batch 400 Loss 0.0678
# Epoch 38 Batch 500 Loss 0.0683
# Epoch 38 Batch 600 Loss 0.0973
# Epoch 38 Batch 700 Loss 0.0606
# Epoch 38 Batch 800 Loss 0.0586
# Epoch 38 Batch 900 Loss 0.0854
# Epoch 38 Batch 1000 Loss 0.0873
# Epoch 38 Batch 1100 Loss 0.0760
# Epoch 38 Batch 1200 Loss 0.0630
# Epoch 38 Loss 0.0742
# Time taken for 1 epoch 84.2963137626648 sec
#
# Epoch 39 Batch 0 Loss 0.0485
# Epoch 39 Batch 100 Loss 0.0488
# Epoch 39 Batch 200 Loss 0.0508
# Epoch 39 Batch 300 Loss 0.0770
# Epoch 39 Batch 400 Loss 0.0474
# Epoch 39 Batch 500 Loss 0.0490
# Epoch 39 Batch 600 Loss 0.0471
# Epoch 39 Batch 700 Loss 0.0889
# Epoch 39 Batch 800 Loss 0.0766
# Epoch 39 Batch 900 Loss 0.0679
# Epoch 39 Batch 1000 Loss 0.1016
# Epoch 39 Batch 1100 Loss 0.0979
# Epoch 39 Batch 1200 Loss 0.1050
# Epoch 39 Loss 0.0727
# Time taken for 1 epoch 83.41336750984192 sec
#
# Epoch 40 Batch 0 Loss 0.0581
# Epoch 40 Batch 100 Loss 0.0489
# Epoch 40 Batch 200 Loss 0.0686
# Epoch 40 Batch 300 Loss 0.0558
# Epoch 40 Batch 400 Loss 0.0513
# Epoch 40 Batch 500 Loss 0.0545
# Epoch 40 Batch 600 Loss 0.0634
# Epoch 40 Batch 700 Loss 0.0999
# Epoch 40 Batch 800 Loss 0.0650
# Epoch 40 Batch 900 Loss 0.0930
# Epoch 40 Batch 1000 Loss 0.1475
# Epoch 40 Batch 1100 Loss 0.1035
# Epoch 40 Batch 1200 Loss 0.0805
# Epoch 40 Loss 0.0739
# Time taken for 1 epoch 84.1484854221344 sec
#
# Epoch 41 Batch 0 Loss 0.0756
# Epoch 41 Batch 100 Loss 0.0488
# Epoch 41 Batch 200 Loss 0.0525
# Epoch 41 Batch 300 Loss 0.1098
# Epoch 41 Batch 400 Loss 0.0518
# Epoch 41 Batch 500 Loss 0.0550
# Epoch 41 Batch 600 Loss 0.0504
# Epoch 41 Batch 700 Loss 0.0767
# Epoch 41 Batch 800 Loss 0.0960
# Epoch 41 Batch 900 Loss 0.0686
# Epoch 41 Batch 1000 Loss 0.0585
# Epoch 41 Batch 1100 Loss 0.0730
# Epoch 41 Batch 1200 Loss 0.0871
# Epoch 41 Loss 0.0719
# Time taken for 1 epoch 83.27953672409058 sec
#
# Epoch 42 Batch 0 Loss 0.1008
# Epoch 42 Batch 100 Loss 0.0420
# Epoch 42 Batch 200 Loss 0.0785
# Epoch 42 Batch 300 Loss 0.0546
# Epoch 42 Batch 400 Loss 0.0992
# Epoch 42 Batch 500 Loss 0.0751
# Epoch 42 Batch 600 Loss 0.0853
# Epoch 42 Batch 700 Loss 0.1365
# Epoch 42 Batch 800 Loss 0.0909
# Epoch 42 Batch 900 Loss 0.0718
# Epoch 42 Batch 1000 Loss 0.0728
# Epoch 42 Batch 1100 Loss 0.1598
# Epoch 42 Batch 1200 Loss 0.0719
# Epoch 42 Loss 0.0744
# Time taken for 1 epoch 84.1163182258606 sec
#
# Epoch 43 Batch 0 Loss 0.1032
# Epoch 43 Batch 100 Loss 0.0884
# Epoch 43 Batch 200 Loss 0.0587
# Epoch 43 Batch 300 Loss 0.0467
# Epoch 43 Batch 400 Loss 0.0826
# Epoch 43 Batch 500 Loss 0.1090
# Epoch 43 Batch 600 Loss 0.0751
# Epoch 43 Batch 700 Loss 0.0538
# Epoch 43 Batch 800 Loss 0.0516
# Epoch 43 Batch 900 Loss 0.0836
# Epoch 43 Batch 1000 Loss 0.0659
# Epoch 43 Batch 1100 Loss 0.1199
# Epoch 43 Batch 1200 Loss 0.1095
# Epoch 43 Loss 0.0755
# Time taken for 1 epoch 83.40661811828613 sec
#
# Epoch 44 Batch 0 Loss 0.0374
# Epoch 44 Batch 100 Loss 0.0545
# Epoch 44 Batch 200 Loss 0.0551
# Epoch 44 Batch 300 Loss 0.0718
# Epoch 44 Batch 400 Loss 0.0395
# Epoch 44 Batch 500 Loss 0.0763
# Epoch 44 Batch 600 Loss 0.0721
# Epoch 44 Batch 700 Loss 0.0519
# Epoch 44 Batch 800 Loss 0.0605
# Epoch 44 Batch 900 Loss 0.0702
# Epoch 44 Batch 1000 Loss 0.1218
# Epoch 44 Batch 1100 Loss 0.0672
# Epoch 44 Batch 1200 Loss 0.0997
# Epoch 44 Loss 0.0758
# Time taken for 1 epoch 84.07606840133667 sec
#
# Epoch 45 Batch 0 Loss 0.0480
# Epoch 45 Batch 100 Loss 0.0647
# Epoch 45 Batch 200 Loss 0.0578
# Epoch 45 Batch 300 Loss 0.0607
# Epoch 45 Batch 400 Loss 0.0581
# Epoch 45 Batch 500 Loss 0.0514
# Epoch 45 Batch 600 Loss 0.0573
# Epoch 45 Batch 700 Loss 0.0775
# Epoch 45 Batch 800 Loss 0.0875
# Epoch 45 Batch 900 Loss 0.0868
# Epoch 45 Batch 1000 Loss 0.0856
# Epoch 45 Batch 1100 Loss 0.0821
# Epoch 45 Batch 1200 Loss 0.0730
# Epoch 45 Loss 0.0773
# Time taken for 1 epoch 83.29999732971191 sec
#
# Epoch 46 Batch 0 Loss 0.0984
# Epoch 46 Batch 100 Loss 0.0567
# Epoch 46 Batch 200 Loss 0.0633
# Epoch 46 Batch 300 Loss 0.0830
# Epoch 46 Batch 400 Loss 0.0756
# Epoch 46 Batch 500 Loss 0.0734
# Epoch 46 Batch 600 Loss 0.0524
# Epoch 46 Batch 700 Loss 0.0607
# Epoch 46 Batch 800 Loss 0.0627
# Epoch 46 Batch 900 Loss 0.0855
# Epoch 46 Batch 1000 Loss 0.1176
# Epoch 46 Batch 1100 Loss 0.0666
# Epoch 46 Batch 1200 Loss 0.1121
# Epoch 46 Loss 0.0770
# Time taken for 1 epoch 84.26828861236572 sec
#
# Epoch 47 Batch 0 Loss 0.0360
# Epoch 47 Batch 100 Loss 0.0473
# Epoch 47 Batch 200 Loss 0.0894
# Epoch 47 Batch 300 Loss 0.0796
# Epoch 47 Batch 400 Loss 0.0316
# Epoch 47 Batch 500 Loss 0.0641
# Epoch 47 Batch 600 Loss 0.0618
# Epoch 47 Batch 700 Loss 0.0778
# Epoch 47 Batch 800 Loss 0.0880
# Epoch 47 Batch 900 Loss 0.1076
# Epoch 47 Batch 1000 Loss 0.1352
# Epoch 47 Batch 1100 Loss 0.1246
# Epoch 47 Batch 1200 Loss 0.1002
# Epoch 47 Loss 0.0788
# Time taken for 1 epoch 83.47906017303467 sec
#
# Epoch 48 Batch 0 Loss 0.0803
# Epoch 48 Batch 100 Loss 0.0573
# Epoch 48 Batch 200 Loss 0.0949
# Epoch 48 Batch 300 Loss 0.0675
# Epoch 48 Batch 400 Loss 0.0362
# Epoch 48 Batch 500 Loss 0.0739
# Epoch 48 Batch 600 Loss 0.0988
# Epoch 48 Batch 700 Loss 0.0720
# Epoch 48 Batch 800 Loss 0.0765
# Epoch 48 Batch 900 Loss 0.0789
# Epoch 48 Batch 1000 Loss 0.1118
# Epoch 48 Batch 1100 Loss 0.0825
# Epoch 48 Batch 1200 Loss 0.1240
# Epoch 48 Loss 0.0782
# Time taken for 1 epoch 84.29609251022339 sec
#
# Epoch 49 Batch 0 Loss 0.0526
# Epoch 49 Batch 100 Loss 0.0289
# Epoch 49 Batch 200 Loss 0.0547
# Epoch 49 Batch 300 Loss 0.0422
# Epoch 49 Batch 400 Loss 0.0680
# Epoch 49 Batch 500 Loss 0.0814
# Epoch 49 Batch 600 Loss 0.1092
# Epoch 49 Batch 700 Loss 0.0714
# Epoch 49 Batch 800 Loss 0.0798
# Epoch 49 Batch 900 Loss 0.0901
# Epoch 49 Batch 1000 Loss 0.0724
# Epoch 49 Batch 1100 Loss 0.0913
# Epoch 49 Batch 1200 Loss 0.1274
# Epoch 49 Loss 0.0785
# Time taken for 1 epoch 83.44137287139893 sec
#
# Epoch 50 Batch 0 Loss 0.0814
# Epoch 50 Batch 100 Loss 0.0414
# Epoch 50 Batch 200 Loss 0.0709
# Epoch 50 Batch 300 Loss 0.0726
# Epoch 50 Batch 400 Loss 0.0887
# Epoch 50 Batch 500 Loss 0.0945
# Epoch 50 Batch 600 Loss 0.0874
# Epoch 50 Batch 700 Loss 0.0775
# Epoch 50 Batch 800 Loss 0.0703
# Epoch 50 Batch 900 Loss 0.0685
# Epoch 50 Batch 1000 Loss 0.1079
# Epoch 50 Batch 1100 Loss 0.0739
# Epoch 50 Batch 1200 Loss 0.1442
# Epoch 50 Loss 0.0810
# Time taken for 1 epoch 84.34744024276733 sec

# %% [markdown]
# ## Translate
#
# * The evaluate function is similar to the training loop, except we don't use *teacher forcing* here. The input to the decoder at each time step is its previous predictions along with the hidden state and the encoder output.
# * Stop predicting when the model predicts the *end token*.
# * And store the *attention weights for every time step*.
#
# Note: The encoder output is calculated only once for one input.

# %%
def evaluate(sentence):
  attention_plot = np.zeros((max_length_targ, max_length_inp))

  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inputs = tf.convert_to_tensor(inputs)

  result = ''

  hidden = [tf.zeros((1, units))]
  enc_hidden = encoder(inputs, hidden)

  dec_hidden = enc_hidden
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

  for t in range(max_length_targ):
    predictions, dec_hidden = decoder(dec_input, dec_hidden)

    # storing the attention weights to plot later on
    predicted_id = tf.argmax(predictions[0]).numpy()
    result += targ_lang.index_word[predicted_id] + ' '

    if targ_lang.index_word[predicted_id] == '<end>':
      return result, sentence

    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %% [markdown]
# ## Restore the latest checkpoint and test

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
translate('cómo estás.')
# Out:
# Input: <start> c mo est s . <end>
# Predicted translation: you're sorry . <end>

# %%
translate('No puedo ir.')
# Out:
# Input: <start> no puedo ir . <end>
# Predicted translation: i can't go . <end>

# %%
translate(u'¿Todavía estás en casa?')
# Out:
# Input: <start> todav a est s en casa ? <end>
# Predicted translation: are you still at home ? <end>

# %%
translate(u'Intenta hacerlo.')
# Out:
# Input: <start> intenta hacerlo . <end>
# Predicted translation: try to do it . <end>

# %%
translate(u'Me encanta cuando nieva.')
# Out:
# Input: <start> me encanta cuando nieva . <end>
# Predicted translation: i love when it owned . <end>
